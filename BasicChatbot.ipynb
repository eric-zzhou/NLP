# %% [markdown]
# <a href="https://colab.research.google.com/github/ericzhou16/NLP/blob/master/BasicChatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Created based on [this article](https://medium.com/analytics-vidhya/a-simple-chatbot-using-python-and-nltk-c413b40e9441).

# %%
# Connecting to Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Imports
import pandas as pd
import random 
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
nltk.download('all')

# %%
# Greetings, basically maps different user greetings to a random output greeting
greet_in = ('hey', 'sup', 'waddup', 'wassup', 'hi', 'hello', 'good day','heya', 'hiya', 'howdy',
'greetings', 'yo', 'ahoy', 'ello')
greet_out = ['hey', 'hello', 'hi there', 'hi', 'heya', 'hiya', 'howdy', 'greetings', '*nods*', '\'ello']

def greeting(sent):
   for word in sent.split():
      if word.lower() in greet_in:
         return random.choice(greet_out)

# %%
# Small talk, basic questions and responses
small_talk_responses = {
'how are you': 'I am fine. Thank you for asking',
'how are you doing': 'I am fine. Thank you for asking',
'how do you do': 'I am good. Thanks for asking',
'how are you holding up': 'I am fine. Thank you for asking',
'how is it going': 'It is going great. Thank you for asking',
'good morning': 'Good Morning',
'good afternoon': 'Good Afternoon',
'good evening': 'Good Evening',
'good day': 'Good day to you too',
'whats up': 'The sky',
'sup': 'The sky',
'thanks': 'Don\'t mention it. You are welcome',
'thank you': 'Don\'t mention it. You are welcome'
}

# Getting string array of all responses
small_talk = small_talk_responses.values()
small_talk = [str (item) for item in small_talk]

# Find the closest small talk
def tfidf_cosim_smalltalk(doc, query):
   query = [query]
   tf = TfidfVectorizer(use_idf=True, sublinear_tf=True)
   # Converts words to vectors
   tf_doc = tf.fit_transform(doc)
   tf_query = tf.transform(query)
   # Get cosine similarity
  #  print(f"cossimunflat: {cosine_similarity(tf_doc,tf_query)}")
  #  print(f"cossimflat: {cosine_similarity(tf_doc,tf_query).flatten()}")
   cosineSimilarities = cosine_similarity(tf_doc,tf_query).flatten()  # converts vert to hor list, one for each of the small talk qs
   related_docs_indices = cosineSimilarities.argsort()[:-2:-1]  # gets last value of the sorted list
   # Only responds if the similarity is higher than threshold of 0.9
   if (cosineSimilarities[related_docs_indices] > 0.98):
      ans = [small_talk[i] for i in related_docs_indices[:1]]
      return ans[0]

# %%
# Managing name
def naming(name):
   a = name.split()
   nam = ''
   if('my name is' in name):
      for j in a:
         if j not in 'mynameis':
            nam = j
   elif('call me' in name):
      for j in a:
         if j not in 'callme':
            nam = j
   elif('name is' in name):
      for j in a:
         if j not in 'nameis':
            nam = j
   elif('change my name to' in name):
      for j in a:
         if j not in 'changemynameto':
            nam = j
   elif('change name to' in name):
      for j in a:
         if j not in 'changenameto':
            nam = j
   else:
      nam = name
   nam = nam[0:1].upper() + nam[1:]
   return nam

# %%
# https://www.microsoft.com/en-us/download/details.aspx?id=a333c41c-9704-4412-9fbc-15bb1fb7f5c3
# Reading and cleaning data
data = pd.read_csv("/content/gdrive/MyDrive/WikiQA.tsv", sep='\t')
data = data[data['Label'] == 1]
data = data.reset_index()
data = data.drop(['QuestionID', 'DocumentID', 'DocumentTitle', 
                  'SentenceID', 'Label', 'index'], axis=1)
data
# Out:
#                                              Question  \
# 0     HOW AFRICAN AMERICANS WERE IMMIGRATED TO THE US
# 1                       how are glacier caves formed?
# 2                              how a water pump works
# 3              how big is bmc software in houston, tx
# 4              how big is bmc software in houston, tx
# ...                                               ...
# 1464                     What is an economic feature?
# 1465              what is the average american income
# 1466                  When was Apple Computer founded
# 1467                    what is section eight housing
# 1468                    what is section eight housing
#
#                                                Sentence
# 0     As such, African immigrants are to be distingu...
# 1     A glacier cave is a cave formed within the ice...
# 2     Pumps operate by some mechanism (typically rec...
# 3     Employing over 6,000, BMC is often credited wi...
# 4     For 2011, the company recorded an annual reven...
# ...                                                 ...
# 1464  At the turn of the 21st century, the expanding...
# 1465  U.S. median household income fell from $51,144...
# 1466  The company was founded on April 1, 1976, and ...
# 1467  Section 8 of the Housing Act of 1937 (), often...
# 1468  It operates through several programs, the larg...
#
# [1469 rows x 2 columns]

# %%
# Combining into a list with all the text
symbs = '!@#$%^&*()<>,;?\''
lm = WordNetLemmatizer()

all_text = {}
og_text = {}
for index, row in data.iterrows():
    question = []
    for word in nltk.pos_tag(nltk.word_tokenize(''.join(
        filter(lambda i: i not in symbs, row['Question'])).lower()),
         tagset="universal"):
      w, p = word
      # print(w, p)
      if p == "VERB":
        question.append(lm.lemmatize(w, pos="v"))
      elif p == "NOUN":
        question.append(lm.lemmatize(w, pos="n"))
      elif p == "ADJ":
        question.append(lm.lemmatize(w, pos="a"))
      else:
        question.append(w)
    question = ' '.join(question)
    og_text[question] = row['Question']
    all_text[question] = row['Sentence']
all_text = [str(item).lower() for item in all_text]
print(len(all_text))
print(og_text)

stemmed_doc = []
for text in all_text:
  tp = []
  for word in nltk.pos_tag(nltk.word_tokenize(text), tagset="universal"):
    w, p = word
    # print(w, p)
    if p == "VERB":
      tp.append(lm.lemmatize(w, pos="v"))
    elif p == "NOUN":
      tp.append(lm.lemmatize(w, pos="n"))
    elif p == "ADJ":
      tp.append(lm.lemmatize(w, pos="a"))
    else:
      tp.append(w)
  stemmed_doc.append(' '.join(tp))
print(len(stemmed_doc))
print(stemmed_doc)
tf = TfidfVectorizer(use_idf=True, sublinear_tf=True, stop_words=stopwords.words('english'))
tf_doc = tf.fit_transform(stemmed_doc)
# print(tf_doc.todense())

# Stemming and figuring out importance of terms using tfidf
def stem_tfidf(query):
  #  query = [query]
   stemmed_query = []
   for word in nltk.pos_tag(nltk.word_tokenize(query.lower()),
         tagset="universal"):
      w, p = word
      # print(w, p)
      if p == "VERB":
        stemmed_query.append(lm.lemmatize(w, pos="v"))
      elif p == "NOUN":
        stemmed_query.append(lm.lemmatize(w, pos="n"))
      elif p == "ADJ":
        stemmed_query.append(lm.lemmatize(w, pos="a"))
      else:
        stemmed_query.append(w)
   stemmed_query = [' '.join(stemmed_query)]
   tf_query = tf.transform(stemmed_query)
   return tf_query
  
# Getting cosine similarity between things and getting the answer
def cos_sim(x):
  # print(tf_doc)
  # print(x)
  cosineSimilarities = cosine_similarity(tf_doc, x).flatten()
  # print(list(cosineSimilarities))
  # print(list(cosineSimilarities.argsort()))
  related_docs_indices = cosineSimilarities.argsort()[:-2:-1]
  # print(related_docs_indices)
  if (cosineSimilarities[related_docs_indices] > 0.5):
     ans = [data.loc[data['Question'] == og_text[all_text[i]]] for i in related_docs_indices[:1]]
     # print(ans)
     for item in ans:
        return item['Sentence'].iloc[0]
  else:
     k = 'I am sorry, I cannot help you with this one. Hope to in the future. Cheers :)'
     return k
# Out:
# 1237
# {'how african american be immigrate to the us': 'HOW AFRICAN AMERICANS WERE IMMIGRATED TO THE US', 'how be glacier cave form': 'how are glacier caves formed?', 'how a water pump work': 'how a water pump works', 'how big be bmc software in houston tx': 'how big is bmc software in houston, tx', 'how much be 1 tablespoon of water': 'how much is 1 tablespoon of water', 'how much be the harry potter movie worth': 'how much are the harry potter movies worth', 'how a rocket engine work': 'how a rocket engine works', 'how old be sue lyon when she make lolita': 'how old was sue lyon when she made lolita', 'how be cholera and typhus transmit and prevent': 'how are cholera and typhus transmitted and prevented', 'how do anne frank die': 'how did anne frank die', 'how be aircraft radial engine build': 'how are aircraft radial engines built', 'how deep can be drill for deep underwater': 'how deep can be drill for deep underwater', 'how old be monica lewinsky during the affair': 'how old was monica lewinsky during the affair', 'how long be frank sinatra famous': 'how long was frank sinatra famous', 'how be antibody use in': 'how are antibodies used in', 'how much be jk rowling worth': 'how much is jk rowling worth', 'how big be auburndale florida': 'how big is auburndale florida', 'how old be kirk douglas the actor': 'how old is kirk douglas, the actor?', 'how old be the singer bob seger': 'how old is the singer bob seger', 'how long be i love lucy on the air': 'how long was i love lucy on the air', 'how long be richard nixon a president': 'how long was richard nixon a president', 'how much be centavos in mexico': 'HOW MUCH IS CENTAVOS IN MEXICO', 'how long be mickie james with wwe': 'How long was Mickie James with WWE?', 'how do armando christian perez become famous': 'how did armando christian perez become famous', 'how old be the twin tower when destroyed': 'how old were the twin towers when destroyed', 'how be the of electron in each shell determine': 'how are the # of electrons in each shell determined', 'how many president of the us': 'how many presidents of the us', 'how old be beatrice author': 'how old is beatrice author', 'how be public school fund': 'how are public schools funded', 'what happen to the light independent reaction of photosynthesis': 'what happens  to the light independent reactions of photosynthesis?', 'how do interlibrary loan work': 'how does interlibrary loan work', 'what do mia hamm do his work': 'what did mia hamm do his work', 'what bacteria grow on macconkey agar': 'what bacteria grow on macconkey agar', 'what country be under the buddhism religion': 'what countries are under the buddhism religion', 'how do wild bill father die': "how did wild bill's father die", 'how many land rover have land on mar': 'how many land rovers have landed on mars', 'how do forensic auditor examine financial reporting': 'how do forensic auditors examine financial reporting', 'what bird family be the owl': 'what bird family is the owl', 'how do harmon killebrew get strong': 'how did harmon killebrew get strong', 'what do the augur use to interpret the will of the god': 'What did the augurs use to interpret the will of the gods?', 'how much do waterboy gross': 'How much did Waterboy grossed', 'what county be farmington hill mi in': 'What county is Farmington Hills, MI in?', 'what do a groundhog look for on groundhog day': 'what does a groundhog look for on groundhog day', 'what committee be joint committee': 'What committees are joint committees', 'how many stripe on the flag': 'how many stripes on the flag', 'how many state and territory be within india': 'How many states and territories are within India?', 'how be whooping cough distinguish from similar disease': 'how is whooping cough distinguished from similar diseases', 'what county be galveston in texas': 'what county is galveston in texas', 'what city be in the bahamas': 'what cities are in the bahamas', 'how many school be in the big ten': 'how many schools are in the big t ...
# 1237
# ['how african american be immigrate to the us', 'how be glacier cave form', 'how a water pump work', 'how big be bmc software in houston tx', 'how much be 1 tablespoon of water', 'how much be the harry potter movie worth', 'how a rocket engine work', 'how old be sue lyon when she make lolita', 'how be cholera and typhus transmit and prevent', 'how do anne frank die', 'how be aircraft radial engine build', 'how deep can be drill for deep underwater', 'how old be monica lewinsky during the affair', 'how long be frank sinatra famous', 'how be antibody use in', 'how much be jk rowling worth', 'how big be auburndale florida', 'how old be kirk douglas the actor', 'how old be the singer bob seger', 'how long be i love lucy on the air', 'how long be richard nixon a president', 'how much be centavos in mexico', 'how long be mickie james with wwe', 'how do armando christian perez become famous', 'how old be the twin tower when destroyed', 'how be the of electron in each shell determine', 'how many president of the us', 'how old be beatrice author', 'how be public school fund', 'what happen to the light independent reaction of photosynthesis', 'how do interlibrary loan work', 'what do mia hamm do his work', 'what bacteria grow on macconkey agar', 'what country be under the buddhism religion', 'how do wild bill father die', 'how many land rover have land on mar', 'how do forensic auditor examine financial reporting', 'what bird family be the owl', 'how do harmon killebrew get strong', 'what do the augur use to interpret the will of the god', 'how much do waterboy gross', 'what county be farmington hill mi in', 'what do a groundhog look for on groundhog day', 'what committee be joint committee', 'how many stripe on the flag', 'how many state and territory be within india', 'how be whooping cough distinguish from similar disease', 'what county be galveston in texas', 'what city be in the bahamas', 'how many school be in the big ten', 'how be single malt scotch make', 'what composer use sound mass', 'how do you play spade', 'what continent be australia', 'what cause heart disease', 'what country do immigrant come from during the immigration', 'how many people live in atlanta georgia', 'what do it mean to be a commonwealth state', 'how long can you be in the supreme court', 'what county in texas be conroe locate in', 'what can sql 2005 do', 'how many people be kill in the oklahoma city bombing', 'what group take home the award for best rock album at the australian recording industry association aria music award', 'how do a dredge work', 'what do benedict arnold die', 'how many world series do curt schilling have', 'how many port be there in networking', 'what area code be 479', 'what do arraignment mean', 'what do chaucer do', 'what do be and pm stand for', 'how be canadas health care', 'how many xbox 360 game be there', 'how do pineapple grow', 'what country do wine originate in', 'how many district be in west bengal', 'how many town in new hampshire', 'what do salesforce.com do', 'what do 1 year mean to the planet', 'what be feedback mechanism in plant during respiration', 'how fire extinguisher work', 'what do righteousness mean', 'what country be in central america', 'how do a steam engine work', 'what county be tacoma washington in', 'what county be chula vista ca in', 'what do isaac newton do', 'what do the universal law of gravitation state', 'how do a dim sum restaurant work', 'how many us soldier kill in iraq war', 'how many planet be jupiter away from the sun', 'what city be the convention when gerald ford be nominate', 'how many professional hockey team in canada', 'what county be northville mi', 'how many game do brett favre start in a row', 'what do a vote to table a motion mean', 'what do the class mean for sdhc card', 'what do porcupine eat', 'what do elijah mccoy invent', 'how many apple store be there in total', 'what do the idea of effective nuclear charge tell us', 'how be jerky make', 'what domain be eu', 'what do the name ...

# %%
# Main loop
BOT_NAME = "Bob"
n = input(f'\nHello, my name is {BOT_NAME}. What is your name?:\t')
name = naming(n)  # naming function
while(True):
  # User query
  query = input(f'\nHi {name}, I am {BOT_NAME}. How can I help you? If you want to exit, type Bye. : \t')
  query = ''.join((filter(lambda i: i not in symbs, query.lower())))
  # Exit
  if(query=='bye'):
    print(f'\n{BOT_NAME}: This is {BOT_NAME} signing off. Bye, take care {name}')
    break
  
  # Changing names
  elif('my name is' in query or 'call me' in query or 'name is' in query or 'change my name to' in query or 'change name to' in query):
    name = naming(query)
    print(f'\n{BOT_NAME}: Your name is {name}')
  elif('what' in query and 'my' in query and 'name' in query):
    print(name)
  elif ('what' in query and 'your' in query and 'name' in query):
    print(f"My name is {BOT_NAME}. Nice to meet you!")
  # Greeting
  elif(greeting(query)!=None):
        print(f'\n{BOT_NAME}: {greeting(query)} {name}')
  # Small talk
  elif(tfidf_cosim_smalltalk(small_talk_responses, query)!=None):
      x = tfidf_cosim_smalltalk(small_talk_responses, query)
      print(f'\n{BOT_NAME}: {x}')
  # Searching through corpus fo response
  else:
      x = stem_tfidf(query)
      g = cos_sim(x)
      print(f'\n{BOT_NAME}: {g}')
# Out:
# Hello, my name is Bob. What is your name?:	eri
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b4aa91f7d1e7> in <module>
#       2 BOT_NAME = "Bob"
#       3 n = input(f'\nHello, my name is {BOT_NAME}. What is your name?:\t')
# ----> 4 name = naming(n)  # naming function
#       5 while(True):
#       6   # User query
#
# NameError: name 'naming' is not defined
