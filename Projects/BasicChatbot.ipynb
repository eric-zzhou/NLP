# %% [markdown]
# <a href="https://colab.research.google.com/github/ericzhou16/NLP/blob/master/Projects/BasicChatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Created based on [this article](https://medium.com/analytics-vidhya/a-simple-chatbot-using-python-and-nltk-c413b40e9441).

# %%
# Connecting to Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Imports
import pandas as pd
import random 
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# Greetings, basically maps different user greetings to a random output greeting
greet_in = ('hey', 'sup', 'waddup', 'wassup', 'hi', 'hello', 'good day','heya', 'hiya', 'howdy',
'greetings', 'yo', 'ahoy', 'ello')
greet_out = ['hey', 'hello', 'hi there', 'hi', 'heya', 'hiya', 'howdy', 'greetings', '*nods*', '\'ello']

def greeting(sent):
   for word in sent.split():
      if word.lower() in greet_in:
         return random.choice(greet_out)

# %%
# Small talk, basic questions and responses
small_talk_responses = {
'how are you': 'I am fine. Thank you for asking',
'how are you doing': 'I am fine. Thank you for asking',
'how do you do': 'I am good. Thanks for asking',
'how are you holding up': 'I am fine. Thank you for asking',
'how is it going': 'It is going great. Thank you for asking',
'good morning': 'Good Morning',
'good afternoon': 'Good Afternoon',
'good evening': 'Good Evening',
'good day': 'Good day to you too',
'whats up': 'The sky',
'sup': 'The sky',
'thanks': 'Don\'t mention it. You are welcome',
'thank you': 'Don\'t mention it. You are welcome'
}

# Getting string array of all responses
small_talk = small_talk_responses.values()
small_talk = [str (item) for item in small_talk]

# Find the closest small talk
def tfidf_cosim_smalltalk(doc, query):
   query = [query]
   tf = TfidfVectorizer(use_idf=True, sublinear_tf=True)
   # Converts words to vectors
   tf_doc = tf.fit_transform(doc)
   tf_query = tf.transform(query)
   # Get cosine similarity
  #  print(f"cossimunflat: {cosine_similarity(tf_doc,tf_query)}")
  #  print(f"cossimflat: {cosine_similarity(tf_doc,tf_query).flatten()}")
   cosineSimilarities = cosine_similarity(tf_doc,tf_query).flatten()  # converts vert to hor list, one for each of the small talk qs
   related_docs_indices = cosineSimilarities.argsort()[:-2:-1]  # gets last value of the sorted list
   # Only responds if the similarity is higher than threshold of 0.9
   if (cosineSimilarities[related_docs_indices] > 0.9):
      ans = [small_talk[i] for i in related_docs_indices[:1]]
      return ans[0]

# %%
# Managing name
def naming(name):
   a = name.split()
   if('my name is' in name):
      for j in a:
         if j not in 'mynameis':
            return j
   elif('call me' in name):
      for j in a:
         if j not in 'callme':
            return j
   elif('name is' in name):
      for j in a:
         if j not in 'nameis':
            return j
   elif('change my name to' in name):
      for j in a:
         if j not in 'changemynameto':
            return j
   elif('change name to' in name):
      for j in a:
         if j not in 'changenameto':
            return j
   else:
      return name

# %%
# https://www.microsoft.com/en-us/download/details.aspx?id=a333c41c-9704-4412-9fbc-15bb1fb7f5c3
# Reading and cleaning data
data = pd.read_csv("/content/gdrive/MyDrive/WikiQA.tsv", sep='\t')
data = data[data['Label'] == 1]
data = data.reset_index()
data = data.drop(['QuestionID', 'DocumentID', 'DocumentTitle', 
                  'SentenceID', 'Label', 'index'], axis=1)
data
# Out:
#                                              Question  \
# 0     HOW AFRICAN AMERICANS WERE IMMIGRATED TO THE US
# 1                       how are glacier caves formed?
# 2                              how a water pump works
# 3              how big is bmc software in houston, tx
# 4              how big is bmc software in houston, tx
# ...                                               ...
# 1464                     What is an economic feature?
# 1465              what is the average american income
# 1466                  When was Apple Computer founded
# 1467                    what is section eight housing
# 1468                    what is section eight housing
#
#                                                Sentence
# 0     As such, African immigrants are to be distingu...
# 1     A glacier cave is a cave formed within the ice...
# 2     Pumps operate by some mechanism (typically rec...
# 3     Employing over 6,000, BMC is often credited wi...
# 4     For 2011, the company recorded an annual reven...
# ...                                                 ...
# 1464  At the turn of the 21st century, the expanding...
# 1465  U.S. median household income fell from $51,144...
# 1466  The company was founded on April 1, 1976, and ...
# 1467  Section 8 of the Housing Act of 1937 (), often...
# 1468  It operates through several programs, the larg...
#
# [1469 rows x 2 columns]

# %%
# Combining into a list with all the text
# lm = WordNetLemmatizer()
symbs = '!@#$%^&*()<>,;?\''
ps = PorterStemmer()

all_text = {}
og_text = {}
for index, row in data.iterrows():
    question = ''.join(filter(lambda i: i not in symbs, row['Question']))
    # question = ' '.join(lm.lemmatize(word) for word in question.split())
    question = ' '.join(ps.stem(word.lower()) for word in question.split())
    og_text[question] = row['Question']
    all_text[question] = row['Sentence']
all_text = [str (item) for item in all_text]
print(all_text)
print(og_text)

# stemmed_doc = [lm.lemmatize(w) for w in all_text]
stemmed_doc = [ps.stem(w) for w in all_text]
tf = TfidfVectorizer(use_idf=True, sublinear_tf=True, stop_words=stopwords.words('english'))
tf_doc = tf.fit_transform(stemmed_doc)

# Stemming and figuring out importance of terms using tfidf
def stem_tfidf(query):
   query = [query]
  #  stemmed_query = [lm.lemmatize(w) for w in query]
   stemmed_query = [ps.stem(w) for w in query]
   tf_query = tf.transform(stemmed_query)
   return tf_query
  
# Getting cosine similarity between things and getting the answer
def cos_sim(x):
   cosineSimilarities = cosine_similarity(tf_doc, x).flatten()
   related_docs_indices = cosineSimilarities.argsort()[:-2:-1]
   if (cosineSimilarities[related_docs_indices] > 0.5):
      ans = [data.loc[data['Question'] == og_text[all_text[i]]] for i in related_docs_indices[:1]]
      # print(ans)
      for item in ans:
         return item['Sentence'].iloc[0]
   else:
      k = 'I am sorry, I cannot help you with this one. Hope to in the future. Cheers :)'
      return k
# Out:
# ['how african american were immigr to the us', 'how are glacier cave form', 'how a water pump work', 'how big is bmc softwar in houston tx', 'how much is 1 tablespoon of water', 'how much are the harri potter movi worth', 'how a rocket engin work', 'how old wa sue lyon when she made lolita', 'how are cholera and typhu transmit and prevent', 'how did ann frank die', 'how are aircraft radial engin built', 'how deep can be drill for deep underwat', 'how old wa monica lewinski dure the affair', 'how long wa frank sinatra famou', 'how are antibodi use in', 'how much is jk rowl worth', 'how big is auburndal florida', 'how old is kirk dougla the actor', 'how old is the singer bob seger', 'how long wa i love luci on the air', 'how long wa richard nixon a presid', 'how much is centavo in mexico', 'how long wa micki jame with wwe', 'how did armando christian perez becom famou', 'how old were the twin tower when destroy', 'how are the of electron in each shell determin', 'how mani presid of the us', 'how old is beatric author', 'how are public school fund', 'what happen to the light independ reaction of photosynthesi', 'how doe interlibrari loan work', 'what did mia hamm do hi work', 'what bacteria grow on macconkey agar', 'what countri are under the buddhism religion', 'how did wild bill father die', 'how mani land rover have land on mar', 'how do forens auditor examin financi report', 'what bird famili is the owl', 'how did harmon killebrew get strong', 'what did the augur use to interpret the will of the god', 'how much did waterboy gross', 'what counti is farmington hill mi in', 'what doe a groundhog look for on groundhog day', 'what committe are joint committe', 'how mani stripe on the flag', 'how mani state and territori are within india', 'how is whoop cough distinguish from similar diseas', 'what counti is galveston in texa', 'what citi are in the bahama', 'how mani school are in the big ten', 'how is singl malt scotch made', 'what compos use sound mass', 'how do you play spade', 'what contin is australia', 'what caus heart diseas', 'what countri did immigr come from dure the immigr', 'how mani peopl live in atlanta georgia', 'what doe it mean to be a commonwealth state', 'how long can you be in the suprem court', 'what counti in texa is conro locat in', 'what can sql 2005 do', 'how mani peopl were kill in the oklahoma citi bomb', 'what group took home the award for best rock album at the australian record industri associ aria music award', 'how doe a dredg work', 'what did benedict arnold die', 'how mani world seri did curt schill have', 'how mani port are there in network', 'what area code is 479', 'what doe arraign mean', 'what did chaucer do', 'what doe am and pm stand for', 'how is canada health care', 'how mani xbox 360 game are there', 'how do pineappl grow', 'what countri did wine origin in', 'how mani district are in west bengal', 'how mani town in new hampshir', 'what doe salesforce.com do', 'what doe 1 year mean to the planet', 'what is feedback mechan in plant dure respir', 'how fire extinguish work', 'what doe righteous mean', 'what countri are in central america', 'how doe a steam engin work', 'what counti is tacoma washington in', 'what counti is chula vista ca in', 'what did isaac newton do', 'what doe the univers law of gravit state', 'how doe a dim sum restaur work', 'how mani us soldier kill in iraq war', 'how mani planet is jupit away from the sun', 'what citi wa the convent when gerald ford wa nomin', 'how mani profession hockey team in canada', 'what counti is northvil mi', 'how mani game did brett favr start in a row', 'what doe a vote to tabl a motion mean', 'what doe the class mean for sdhc card', 'what do porcupin eat', 'what did elijah mccoy invent', 'how mani appl store are there in total', 'what doe the idea of effect nuclear charg tell us', 'how is jerki made', 'what domain is eu', 'what doe the name "meister" mean in german', 'what happen on the moon dure the period of late heavi bombard', 'how did  ...
# {'how african american were immigr to the us': 'HOW AFRICAN AMERICANS WERE IMMIGRATED TO THE US', 'how are glacier cave form': 'how are glacier caves formed?', 'how a water pump work': 'how a water pump works', 'how big is bmc softwar in houston tx': 'how big is bmc software in houston, tx', 'how much is 1 tablespoon of water': 'how much is 1 tablespoon of water', 'how much are the harri potter movi worth': 'how much are the harry potter movies worth', 'how a rocket engin work': 'how a rocket engine works', 'how old wa sue lyon when she made lolita': 'how old was sue lyon when she made lolita', 'how are cholera and typhu transmit and prevent': 'how are cholera and typhus transmitted and prevented', 'how did ann frank die': 'how did anne frank die', 'how are aircraft radial engin built': 'how are aircraft radial engines built', 'how deep can be drill for deep underwat': 'how deep can be drill for deep underwater', 'how old wa monica lewinski dure the affair': 'how old was monica lewinsky during the affair', 'how long wa frank sinatra famou': 'how long was frank sinatra famous', 'how are antibodi use in': 'how are antibodies used in', 'how much is jk rowl worth': 'how much is jk rowling worth', 'how big is auburndal florida': 'how big is auburndale florida', 'how old is kirk dougla the actor': 'how old is kirk douglas, the actor?', 'how old is the singer bob seger': 'how old is the singer bob seger', 'how long wa i love luci on the air': 'how long was i love lucy on the air', 'how long wa richard nixon a presid': 'how long was richard nixon a president', 'how much is centavo in mexico': 'HOW MUCH IS CENTAVOS IN MEXICO', 'how long wa micki jame with wwe': 'How long was Mickie James with WWE?', 'how did armando christian perez becom famou': 'how did armando christian perez become famous', 'how old were the twin tower when destroy': 'how old were the twin towers when destroyed', 'how are the of electron in each shell determin': 'how are the # of electrons in each shell determined', 'how mani presid of the us': 'how many presidents of the us', 'how old is beatric author': 'how old is beatrice author', 'how are public school fund': 'how are public schools funded', 'what happen to the light independ reaction of photosynthesi': 'what happens  to the light independent reactions of photosynthesis?', 'how doe interlibrari loan work': 'how does interlibrary loan work', 'what did mia hamm do hi work': 'what did mia hamm do his work', 'what bacteria grow on macconkey agar': 'what bacteria grow on macconkey agar', 'what countri are under the buddhism religion': 'what countries are under the buddhism religion', 'how did wild bill father die': "how did wild bill's father die", 'how mani land rover have land on mar': 'how many land rovers have landed on mars', 'how do forens auditor examin financi report': 'how do forensic auditors examine financial reporting', 'what bird famili is the owl': 'what bird family is the owl', 'how did harmon killebrew get strong': 'how did harmon killebrew get strong', 'what did the augur use to interpret the will of the god': 'What did the augurs use to interpret the will of the gods?', 'how much did waterboy gross': 'How much did Waterboy grossed', 'what counti is farmington hill mi in': 'What county is Farmington Hills, MI in?', 'what doe a groundhog look for on groundhog day': 'what does a groundhog look for on groundhog day', 'what committe are joint committe': 'What committees are joint committees', 'how mani stripe on the flag': 'how many stripes on the flag', 'how mani state and territori are within india': 'How many states and territories are within India?', 'how is whoop cough distinguish from similar diseas': 'how is whooping cough distinguished from similar diseases', 'what counti is galveston in texa': 'what county is galveston in texas', 'what citi are in the bahama': 'what cities are in the bahamas', 'how mani school are in the big ten': 'how many schools are in the big ten', 'how is singl malt scotch ...

# %%
# Main loop
n = input('\nHello, my name is Bob. What is your name?:\t')
name = naming(n)  # naming function
while(True):
  # User query
  query = input(f'\nHi {name}, I am Bob. How can I help you? If you want to exit, type Bye. : \t')
  query = query.lower()
  query = ''.join((filter(lambda i: i not in symbs, query)))
  # Exit
  if(query=='bye'):
    print(f'\nBob: This is Bob signing off. Bye, take care {name}')
    break
  
  # Changing names
  elif('my name is' in query or 'call me' in query or 'name is' in query or 'change my name to' in query or 'change name to' in query):
    name = naming(query)
    print(f'\nBob: Your name is {name}')
  elif('what' in query and 'my' in query and 'name' in query):
    print(name)
  # Greeting
  elif(greeting(query)!=None):
        print(f'\nBob: {greeting(query)} {name}')
  # Small talk
  elif(tfidf_cosim_smalltalk(small_talk_responses, query)!=None):
      x = tfidf_cosim_smalltalk(small_talk_responses, query)
      print(f'\nBob: {x}')
  # Searching through corpus fo response
  else:
      x = stem_tfidf(query)
      g = cos_sim(x)
      print(f'\nBob: {g}')
# Out:
# Hello, my name is Bob. What is your name?:	joe
#
# Hi joe, I am Bob. How can I help you? If you want to exit, type Bye. : 	my name is eric
#
# Bob: Your name is eric
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	what's my name
# eric
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	what's up
#
# Bob: The sky
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	thanks
#
# Bob: Don't mention it. You are welcome
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	what are glacier caves
#
# Bob: A glacier cave is a cave formed within the ice of a glacier .
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	when did john adam become president?
#
# Bob: John Adams (October 30, 1735 ( O.S. October 19, 1735) – July 4, 1826) was the second president of the United States (1797–1801), having earlier served as the first vice president of the United States .
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	how are glacier caves formed?
#
# Bob: A glacier cave is a cave formed within the ice of a glacier .
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	how do glacier caves form
#
# Bob: I am good. Thanks for asking
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	what's linkedin for
#
# Bob: LinkedIn () is a social networking website for people in professional occupations.
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	what's the ship in moby dick
#
# Bob: The story tells the adventures of wandering sailor Ishmael , and his voyage on the whaleship Pequod , commanded by Captain Ahab.
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	what is kanji language
#
# Bob: Kanji (; ) are the adopted logographic Chinese characters ( hanzi ) that are used in the modern Japanese writing system along with hiragana (ひらがな, ), katakana (カタカナ, ), Hindu-Arabic numerals , and the occasional use of the Latin alphabet .
#
# Hi eric, I am Bob. How can I help you? If you want to exit, type Bye. : 	bye
#
# Bob: This is Bob signing off. Bye, take care eric
